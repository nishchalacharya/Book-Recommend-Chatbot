# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv("../data/cleaned_book_daatset.csv")

# %%
data.head()
# Out:
#    Unnamed: 0  book_id                                              title  \
# 0           0        1            The Hunger Games (The Hunger Games, #1)
# 1           1        2  Harry Potter and the Sorcerer's Stone (Harry P...
# 2           2        3                            Twilight (Twilight, #1)
# 3           3        4                              To Kill a Mockingbird
# 4           4        5                                   The Great Gatsby
#
#                        authors  average_rating  \
# 0              Suzanne Collins            4.34
# 1  J.K. Rowling, Mary GrandPré            4.44
# 2              Stephenie Meyer            3.57
# 3                   Harper Lee            4.25
# 4          F. Scott Fitzgerald            3.89
#
#                                                 text
# 0  The Hunger Games (The Hunger Games, #1) by Suz...
# 1  Harry Potter and the Sorcerer's Stone (Harry P...
# 2         Twilight (Twilight, #1) by Stephenie Meyer
# ...

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'book_id', 'title', 'authors', 'average_rating', 'text'], dtype='object')

# %%
# Drop the index column if it exists
if 'index' in data.columns:
    data = data.drop(columns=['index'])

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'book_id', 'title', 'authors', 'average_rating', 'text'], dtype='object')

# %%
if 'Unnamed: 0' in df.columns:
    data = data.drop(columns=['Unnamed: 0'])

# %%
if 'Unnamed' in data.columns:
    data=data.drop(columns=['Unnamed'],inplace=True)

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'book_id', 'title', 'authors', 'average_rating', 'text'], dtype='object')

# %%
data.head()
# Out:
#    Unnamed: 0  book_id                                              title  \
# 0           0        1            The Hunger Games (The Hunger Games, #1)
# 1           1        2  Harry Potter and the Sorcerer's Stone (Harry P...
# 2           2        3                            Twilight (Twilight, #1)
# 3           3        4                              To Kill a Mockingbird
# 4           4        5                                   The Great Gatsby
#
#                        authors  average_rating  \
# 0              Suzanne Collins            4.34
# 1  J.K. Rowling, Mary GrandPré            4.44
# 2              Stephenie Meyer            3.57
# 3                   Harper Lee            4.25
# 4          F. Scott Fitzgerald            3.89
#
#                                                 text
# 0  The Hunger Games (The Hunger Games, #1) by Suz...
# 1  Harry Potter and the Sorcerer's Stone (Harry P...
# 2         Twilight (Twilight, #1) by Stephenie Meyer
# ...

# %%
data.head()
# Out:
#    Unnamed: 0  book_id                                              title  \
# 0           0        1            The Hunger Games (The Hunger Games, #1)
# 1           1        2  Harry Potter and the Sorcerer's Stone (Harry P...
# 2           2        3                            Twilight (Twilight, #1)
# 3           3        4                              To Kill a Mockingbird
# 4           4        5                                   The Great Gatsby
#
#                        authors  average_rating  \
# 0              Suzanne Collins            4.34
# 1  J.K. Rowling, Mary GrandPré            4.44
# 2              Stephenie Meyer            3.57
# 3                   Harper Lee            4.25
# 4          F. Scott Fitzgerald            3.89
#
#                                                 text
# 0  The Hunger Games (The Hunger Games, #1) by Suz...
# 1  Harry Potter and the Sorcerer's Stone (Harry P...
# 2         Twilight (Twilight, #1) by Stephenie Meyer
# ...

# %%
new_Data=data[['book_id','title','authors','average_rating','text']]

# %%
new_Data.head()
# Out:
#    book_id                                              title  \
# 0        1            The Hunger Games (The Hunger Games, #1)
# 1        2  Harry Potter and the Sorcerer's Stone (Harry P...
# 2        3                            Twilight (Twilight, #1)
# 3        4                              To Kill a Mockingbird
# 4        5                                   The Great Gatsby
#
#                        authors  average_rating  \
# 0              Suzanne Collins            4.34
# 1  J.K. Rowling, Mary GrandPré            4.44
# 2              Stephenie Meyer            3.57
# 3                   Harper Lee            4.25
# 4          F. Scott Fitzgerald            3.89
#
#                                                 text
# 0  The Hunger Games (The Hunger Games, #1) by Suz...
# 1  Harry Potter and the Sorcerer's Stone (Harry P...
# 2         Twilight (Twilight, #1) by Stephenie Meyer
# 3                To Kill a Mockingbird by Harper Lee
# ...

# %%
new_Data.to_csv('../data/cleaned_book_dataset.csv',index=False)

# %%
final=pd.read_csv('../data/cleaned_book_dataset.csv')

# %%
final.head()
# Out:
#    book_id                                              title  \
# 0        1            The Hunger Games (The Hunger Games, #1)
# 1        2  Harry Potter and the Sorcerer's Stone (Harry P...
# 2        3                            Twilight (Twilight, #1)
# 3        4                              To Kill a Mockingbird
# 4        5                                   The Great Gatsby
#
#                        authors  average_rating  \
# 0              Suzanne Collins            4.34
# 1  J.K. Rowling, Mary GrandPré            4.44
# 2              Stephenie Meyer            3.57
# 3                   Harper Lee            4.25
# 4          F. Scott Fitzgerald            3.89
#
#                                                 text
# 0  The Hunger Games (The Hunger Games, #1) by Suz...
# 1  Harry Potter and the Sorcerer's Stone (Harry P...
# 2         Twilight (Twilight, #1) by Stephenie Meyer
# 3                To Kill a Mockingbird by Harper Lee
# ...

# %%
data.to_csv('cleaned_book_dataset.csv',index=False)

# %%
final=pd.read_csv('../data/cleaned_book_dataset.csv')

# %%
final.head()
# Out:
#    Unnamed: 0  book_id                                              title  \
# 0           0        1            The Hunger Games (The Hunger Games, #1)
# 1           1        2  Harry Potter and the Sorcerer's Stone (Harry P...
# 2           2        3                            Twilight (Twilight, #1)
# 3           3        4                              To Kill a Mockingbird
# 4           4        5                                   The Great Gatsby
#
#                        authors  average_rating  \
# 0              Suzanne Collins            4.34
# 1  J.K. Rowling, Mary GrandPré            4.44
# 2              Stephenie Meyer            3.57
# 3                   Harper Lee            4.25
# 4          F. Scott Fitzgerald            3.89
#
#                                                 text
# 0  The Hunger Games (The Hunger Games, #1) by Suz...
# 1  Harry Potter and the Sorcerer's Stone (Harry P...
# 2         Twilight (Twilight, #1) by Stephenie Meyer
# ...
